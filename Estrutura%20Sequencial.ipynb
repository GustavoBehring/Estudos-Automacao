# %% [markdown]
# # Lista de Estrutura Sequencial

# %% [markdown]
# #### 1. Faça um Programa que mostre a mensagem (print) "Alo mundo" na tela.

# %%
print("Alo mundo")
# Out:
# Alo mundo

# %% [markdown]
# #### 2. Faça um Programa que peça um número (input) e então mostre a mensagem: "O número informado foi [número]."

# %%
numero = int(input("Digite um numero: "))
print("O numero digitado foi:", numero) 
print(f"O numero digitado foi: {numero}")
print("O numero digitado foi: {}".format(numero))
# Out:
# O numero digitado foi: 5
# O numero digitado foi: 5

# %% [markdown]
# #### 3. Faça um Programa que peça dois números e imprima a soma.

# %%
numero1 = int(input("Digite o primeiro numero: "))
numero2 = int(input("Digite o segundo numero: "))
soma = numero1 + numero2
print(f"A soma entre {numero1} e {numero2} é igual a {soma}")
print("A soma entre", numero1, "e", numero2, "é igual a", soma)
# Out:
# A soma entre 10 e 20 é igual a 30

# %% [markdown]
# #### 4. Faça um Programa que peça as 4 notas bimestrais de um aluno e mostre a média de todas as notas.

# %%
nota1 = float(input("Digite a primeira nota: "))
nota2 = float(input("Digite a segunda nota: "))
nota3 = float(input("Digite a terceira nota: "))
nota4 = float(input("Digite a quarta nota: "))
media = (nota1 + nota2 + nota3 + nota4) / 4
#media = int(media)    teste para ver se arredonda
print(f"A média entre as notas {nota1}, {nota2}, {nota3} e {nota4} é igual a {media}")
# Out:
# A média entre as notas 10.0, 5.5, 2.6 e 7.0 é igual a 6

# %% [markdown]
# #### 5. Faça um Programa que converta metros para centímetros. Você pode pedir o comprimento em metros para o usuário (input).

# %%
comprimento = float(input("Digite o comprimento do terreno em metros: "))
centimentros = comprimento * 100
print(f"O comprimento de {comprimento} metros corresponde a {centimentros} centímetros.")
# Out:
# O comprimento de 0.01 metros corresponde a 1.0 centímetros.

# %% [markdown]
# #### 6. Faça um Programa que calcule a área de uma sala de um apartamento. Para isso, o seu programa precisa pedir a largura da sala, o comprimento da sala e imprimir a área em m² da sala.

# %%
largura = float(input("Digite a largura da sala em metros: "))
comprimento = float(input("Digite o comprimento da sala em metros: "))
area = largura * comprimento
print(f"A área da sala é de {area} metros quadrados.")
# Out:
# A área da sala é de 5000.0 metros quadrados.

# %% [markdown]
# #### 7. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês. Calcule e mostre o total do seu salário no referido mês.

# %%
lucro = float(input("Quanto você ganha por hora? "))
horas = int(input("Quantas horas você trabalha por mês? "))
salario = lucro * horas
print(f"Seu salário mensal é de R$ {salario}")
print("Seu salario por mês é de R$ " +  str(salario))
print("Seu salário por mês é de R$ {:.2f}".format(salario))
print("Você ganha por hora {} R$ e trabalha {} horas por mês, então seu salário é R${}".format(lucro, horas, salario))
# Out:
# Seu salário mensal é de R$ 404.0
# Seu salario por mês é de R$ 404.0
# Seu salário por mês é de R$ 404.00
# Você ganha por hora 50.5 R$ e trabalha 8 horas por mês, então seu salário é R$404.0

# %% [markdown]
# #### 8. Vamos criar um conversor de temperatura. Faça um Programa que peça a temperatura em graus Fahrenheit, transforme e mostre a temperatura em graus Celsius.
# $C = \frac{5}{9}(F-32)$

# %%
fahrenheit = float(input("Digite a temperatura em Fahrenheit: "))
celsius = (fahrenheit - 32) * 5 / 9
print(f"A temperatura de {fahrenheit} ºF corresponde a {celsius:.1f} ºC. ")
# Out:
# A temperatura de 80.0 ºF corresponde a 26.7 ºC.

# %% [markdown]
# #### 9. Faça um Programa que peça a temperatura em graus Celsius, transforme e mostre em graus Fahrenheit.
# $F = \frac{9}{5}C + 32$

# %%
celsius = float(input("Digite a temperatura em Celsius: "))
fahrenheit = (celsius * 9/5) + 32
print("A temperatura de {:.2f} ºC corresponde a {} ºF. ".format(celsius, fahrenheit))
print(f"A temperatura em {celsius:.2f} ºC corresponde a {fahrenheit:.2f} ºF.")
# Out:
# A temperatura de 30.0 ºC corresponde a 86.0 ºF.
# A temperatura em 30.00 ºC corresponde a 86.00 ºF.

# %% [markdown]
# #### 10. Tendo como dados de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, usando a seguinte fórmula:
# $P = 72,7h - 58$
#
# Lembrando que "algoritmo" nada mais é do que um programa, como todos os outros que você vem fazendo

# %%
height = float(input("Digite sua altura: "))
pounds = 72.7 * height - 58
print(f"Seu peso ideal é de {pounds:.2f} kg.")
# Out:
# Seu peso ideal é de 71.41 kg.

# %% [markdown]
# #### 11. Tendo como dado de entrada a altura (h) de uma pessoa, construa um algoritmo que calcule seu peso ideal, utilizando as seguintes fórmulas:
# ##### a. Para homens: $P = 72,7h - 58$
# ##### b. Para mulheres: $P = 62,1h - 44,7$

# %%
height = float(input("Digite sua altura: "))
poundsM = 72.7 * height - 58
poundsF = 62.1 * height - 44.7
print(f"Seu peso ideal é de {poundsM:.2f} kgs se você for um homem e {poundsF:.2F} se você for uma mulher.")
# Out:
# Seu peso ideal é de 71.41 kgs se você for um homem e 65.84se você for uma mulher.

# %% [markdown]
# #### 12. Faça um Programa que pergunte quanto você ganha por hora e o número de horas trabalhadas no mês.

# %%
lucro = float(input("Quanto você ganha por hora? "))
horas = int(input("Quantas horas você trabalha por mês? "))

# %% [markdown]
# #####  Calcule o salário bruto (horas * salario por hora)

# %%
bruto = lucro * horas
print(f"Seu salário bruto é de R$ {bruto:.2f}")
# Out:
# Seu salário bruto é de R$ 21600.00

# %% [markdown]
# ##### Calcule o desconto do IR (11% do salário bruto)

# %%
IR = bruto * 0.11
print(f"O valor descontado pelo IR é de R$ {IR:.2f}")
# Out:
# O valor descontado pelo IR é de R$ 2376.00

# %% [markdown]
# ##### Calcule o desconto do INSS (8% do salário bruto)

# %%
INSS = bruto * 0.08
print(f"O valor descontado pelo INSS é de R$ {INSS:.2f}")
# Out:
# O valor descontado pelo INSS é de R$ 1728.00

# %% [markdown]
# ##### Calcule o desconto do sindicato (5% do salário bruto)

# %%
sindicato = bruto * 0.05
print(f"O valor descontado pelo sindicado é de R$ {sindicato:.2f})")
# Out:
# O valor descontado pelo sindicado é de R$ 1080.00)

# %% [markdown]
# ##### Calcule o salário líquido (salário bruto - descontos)

# %%
liquido = bruto - IR - INSS - sindicato
print(f"Seu salário líquido é de R$ {liquido:.2f}")
# Out:
# Seu salário líquido é de R$ 16416.00

# %% [markdown]
# #### 13. Faça um programa para uma loja de tintas. O programa deverá pedir o tamanho em metros quadrados da área a ser pintada. Considere que a cobertura da tinta é de 1 litro para cada 3 metros quadrados e que a tinta é vendida em latas de 18 litros, que custam R\$ 80,00. Informe ao usuário a quantidades de latas de tinta a serem compradas e o preço total. (para simplificação nesse momento, não se preocupe em arredondar a quantidade de latas a serem compradas - vamos trabalhar isso em breve)

# %%
tamanho = int(input("Digite o tamanho em m² da área a ser pintada: "))
litros = tamanho / 3
latas = int(litros / 18)
if litros % 18 != 0:
    latas += 1
valor = latas * 80
print(f"Para pintar uma área de {tamanho} m², você precisará de {litros:.2f} litros de tinta, ou seja, {latas:.2f} latas, ao custo total de R$ {valor:.2f}.")
# Out:
# Para pintar uma área de 85 m², você precisará de 28.33 litros de tinta, ou seja, 2.00 latas, ao custo total de R$ 160.00.

# %% [markdown]
# #### 14. Faça um programa que peça o tamanho de um arquivo para download (em MB) e a velocidade de um link de Internet (em Mbps), calcule e informe o tempo aproximado de download do arquivo usando este link (em minutos).
#
# Detalhe: MB significa megabyte, Mb (com b minúsculo) significa megabit. Um megabit é 1/8 de um megabyte.

# %%
tamanho = float(input("Digite o tamanho do arquivo em MB: "))
velocidade = float(input("Digite a velocidade da sua internet em Mbps: "))
tempo_segundos = (tamanho * 8) / velocidade
tempo_minutos = tempo_segundos / 60
print(f"O tempo estimado para download de um arquivo de {tamanho} MB com uma velocidade de {velocidade} Mbps é de {tempo_minutos:.2f} minutos.")
# Out:
# O tempo estimado para download de um arquivo de 1000.0 MB com uma velocidade de 800.0 Mbps é de 0.17 minutos.
