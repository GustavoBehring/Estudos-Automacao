# %%
print("Meu primeiro código")
# Out:
# Meu primeiro código

# %%
print("Mais um código")
# Out:
# Mais um código

# %% [markdown]
# ### Shift enter coloca mais uma celula, ctrl enter faz só aquela ser rodada
#
# ##### Se clicar no markdown e ctrl enter ele deixa um comentário com o tamanho variando de acordo com as quantidades de hashtags
